# %%
print('hello ritik!!')
# Out:
# hello ritik!!

# %% [markdown]
# Python Arithmatic operations

# %%
2*2+2
# Out:
# 6

# %%
7%4
# Out:
# 3

# %%
7/4
# Out:
# 1.75

# %% [markdown]
# Python is dynamically typed

# %%
ritik = 2
riya=3

# %%
raman = ritik * riya
print (type(raman),raman)
# Out:
# <class 'float'> 6.4

# %%
ritik = ritik *2

# %%
ritik
# Out:
# 64

# %% [markdown]
# String operations in python
# Indexing and slicing

# %%
'hello'
# Out:
# 'hello'

# %%
"world ritik"
# Out:
# 'world ritik'

# %%
"this is also a string  I don't like java"
# Out:
# "this is also a string  I don't like java"

# %%
'hello world 1'
'hello world 2'
# Out:
# 'hello world 2'

# %%
print('hello world 1')
print('hello world 2')
# Out:
# hello world 1
# hello world 2

# %%
# \n means new line 

print('hello \n world \n ritik')
# Out:
# hello
#  world
#  ritik

# %%
len ("I'am ritik verma")
# Out:
# 16
